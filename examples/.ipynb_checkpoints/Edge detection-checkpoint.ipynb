# %%
import skimage
import skimage.io as sio
import matplotlib.pyplot as plt
import numpy as np
import cv2 as cv

from skimage.filters import gaussian
from skimage.filters import sobel, prewitt, scharr

# %% [markdown]
# ### Using OpenCv Canny Edge Detector

# %%
img = cv.imread('wellplate.png',0)
edges = cv.Canny(img,2,4,L2gradient = True)
sio.imsave('edges.png',edges)
image = sio.imshow(img)

# %%
image

# %%
fig,ax = plt.subplots(2,1,figsize=(20,20))
ax[0].imshow(img,cmap = 'gray')
ax[0].set_title('Original Image'), ax[0].set_xticks([]), ax[0].set_yticks([])
ax[1].imshow(edges,cmap = 'gray')
ax[1].set_title('Edge Image'), ax[1].set_xticks([]), ax[1].set_yticks([])
# Out:
# (Text(0.5, 1.0, 'Edge Image'), [], [])

# %% [markdown]
#  ### Adding a Gaussian filter, an edge detector, and a threshold all together to make our own mini Canny edge detector:

# %%
gs = gaussian(img, sigma=2)
ed = sobel(gaussian(img, sigma=2))
thre = sobel(gaussian(img, sigma=2)) > 0.03
fig, axes = plt.subplots(2,2,figsize=(19, 10))

axes[0,0].imshow(img, cmap='gray')
axes[0,1].imshow(gs, cmap='gray')
axes[1,0].imshow(ed, cmap='gray')
axes[1,1].imshow(thre, cmap='gray')

# %% [markdown]
# ### Separating the wellplates from the backgroung

# %%
from scipy.ndimage.morphology import binary_fill_holes

filled_wells = binary_fill_holes(thre)
plt.imshow(filled_wells, cmap = 'gray')

# %% [markdown]
# ### Labeling the well plates
# ##### Labeling assigns all the pixels with the same intensities with the same value.

# %%
from skimage.measure import label

lab_wells = label(filled_wells)

fig, ax = plt.subplots()
ax.imshow(lab_wells*10, vmin=0)
ax.axis('off')
# Out:
# (-0.5, 1131.5, 745.5, -0.5)

# %% [markdown]
# #### We can use our labelled image as the input to the function to determine the image properties

# %%
from skimage.measure import regionprops
import pandas as pd

props = regionprops(lab_wells, intensity_image=img)
x = np.zeros(len(props))
y = np.zeros(len(props))
area = np.zeros(len(props))
perim = np.zeros(len(props))
intensity = np.zeros(len(props))

counter = 0
for prop in props:
    x[counter] = prop.centroid[0]
    y[counter] = prop.centroid[1]
    area[counter] = prop.area
    perim[counter] = prop.perimeter
    intensity[counter] = prop.mean_intensity
    
    counter += 1

regionprops = pd.DataFrame({'X': x, 'Y': y, 'Area': area,
                            'Perim': perim, 'Mean Intensity': intensity})

# %% [markdown]
# #### The mean intensity of each well can be used to determine temperature at each well

# %%
regionprops
# Out:
#              X            Y    Area       Perim  Mean Intensity
# 0    42.778657   147.988600  3158.0  208.066017       90.734326
# 1    44.577982   237.182537  3161.0  207.237590       92.628282
# 2    46.172337    56.254054  3145.0  208.066017       89.035930
# 3    47.164345   711.720076  3158.0  207.237590      104.827106
# 4    46.353090   813.170523  3155.0  207.823376      111.813946
# 5    47.857279   629.665817  3139.0  205.823376      102.533928
# 6    50.504453   333.360687  3144.0  206.651804       95.056298
# 7    50.638291   528.205380  3160.0  207.237590      100.629747
# 8    50.654042  1095.351369  3142.0  206.166522       97.638129
# 9    51.509362   429.428118  3151.0  205.823376       98.129483
# 10   51.545224   996.691526  3151.0  206.409163       94.863853
# 11   52.323023   909.437819  3136.0  205.823376       92.935906
# 12  139.012658   146.451683  3239.0  210.066017      104.058351
# 13  140.750000   235.591162  3236.0  209.237590      106.853832
# 14  142.419845    54.724341  3225.0  208.651804      100.142636
# 15  142.548118   811.608267  3242.0  209.237590      115.697101
# 16  143.416461   710.219790  3244.0  210.651804      111.514180
# 17  144.141574   628.120818  3228.0  209.237590      108.925651
# 18  146.737543   331.739709  3231.0  209.823376      109.734448
# 19  146.863398   526.666667  3243.0  210.651804      106.127351
# 20  146.868023  1093.936787  3243.0  211.480231      130.220475
# 21  147.733313   427.898185  3251.0  210.651804      111.793294
# 22  147.737604   995.175855  3247.0  210.651804      126.305205
# 23  148.499071   907.821362  3230.0  208.651804      122.569040
# 24  228.173666   145.560467  3167.0  207.237590       92.180297
# 25  229.993685   234.721503  3167.0  207.237590       94.057783
# 26  231.940219    53.602191  3195.0  208.651804       89.870423
# 27  231.732701   810.754502  3165.0  208.066017      108.761137
# 28  232.586936   709.325024  3169.0  208.066017      107.587883
# 29  233.667502   626.990599  3191.0  207.823376      104.399561
# ..         ...          ...     ...         ...             ...
# 66  510.388734   329.192201  3231.0  210.651804      109.727639
# 67  510.514974   524.065452  3239.0  210.066017      106.196357
# 68  510.510487  1091.380012  3242.0  209.823376      130.275447
# 69  511.404446   425.295153  3239.0  209.823376      111.631368
# 70  511.401356   992.556412  3244.0  209.823376      126.251233
# 71  512.119144   905.207260  3223.0  209.237590      122.096184
# 72  591.862658   142.949367  3160.0  205.823376       91.868987
# 73  593.602147   232.079571  3167.0  207.237590       93.874329
# 74  595.526118    50.950891  3197.0  208.409163       89.969346
# 75  595.281655   808.094411  3167.0  206.994949      108.804231
# 76  596.157296   706.714466  3166.0  207.237590      107.343020
# 77  597.314536   624.408521  3192.0  208.651804      104.474624
# 78  599.893730   328.019122  3190.0  207.823376       96.127900
# 79  599.713834   523.154138  3166.0  207.237590      103.152243
# 80  599.698833  1090.461053  3171.0  208.651804       99.880164
# 81  600.559343   424.383523  3168.0  208.066017      101.085227
# 82  600.569357   991.651639  3172.0  208.066017       97.431589
# 83  601.650828   904.116286  3199.0  208.651804       94.406377
# 84  687.092227   140.326342  3242.0  210.066017      104.434300
# 85  688.798764   229.495209  3235.0  209.237590      106.573416
# 86  690.458333    48.765236  3216.0  208.994949      100.803483
# 87  690.595319   805.538035  3247.0  209.237590      115.370804
# 88  691.447660   704.116379  3248.0  210.651804      111.182882
# 89  692.241765   622.100684  3218.0  209.237590      109.153511
# 90  694.791602   325.796579  3215.0  208.994949      110.262519
# 91  694.899352   520.527632  3239.0  210.066017      106.005557
# 92  694.900031  1087.821660  3241.0  211.480231      126.432274
# 93  695.785009   421.725787  3242.0  209.823376      111.804442
# 94  695.794824   989.053604  3246.0  210.651804      126.560382
# 95  696.596950   901.789916  3213.0  208.409163      122.743231
#
# [96 rows x 5 columns]
