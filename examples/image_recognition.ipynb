# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import skimage
from skimage import io
import matplotlib.pyplot as plt
from skimage import data

# %%
example_image = io.imread('../doc/Lepton_Capture_3.tiff')

# %%
example_image.shape
# Out:
# (95, 120, 160)

# %% [markdown]
# ### The numbers above correspond to number of frames, height, and width.

# %%
example_image[0].dtype
# Out:
# dtype('uint16')

# %% [markdown]
# ### each pixel is 16-bit.

# %%
io.imshow(example_image[50])

# %% [markdown]
# ### When recording radiometric videos with the Lepton, there is no color and no temperature scale. Above, the first frame of the video was selected and a colorscale was automatically appied, with the scale reading temperature values in cK.

# %%
from skimage.exposure import histogram

# %%
 height, width = histogram(example_image[50])
image_hist = plt.plot( width, height, linewidth=1)

# %%
from collections import Counter

data = Counter(width)

data.most_common(1)
# Out:
# [(29417, 1)]

# %%
fig, axes = plt.subplots(figsize=(15, 6), ncols=3)
thresh = [29600, 30400, 30600]

counter = 0
for ax, thres in zip(axes, thresh):
    ax.imshow(example_image[50] > thres)
    ax.axis('off')
    counter += 1
